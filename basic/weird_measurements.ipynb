# %%
from qiskit import QuantumCircuit

# %%
qc = QuantumCircuit(4, 3)
for i in range(4):
    qc.measure(i, i)
# Out:
# ---------------------------------------------------------------------------
# CircuitError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 qc = QuantumCircuit(4, 3)
#       2 for i in range(4):
# ----> 3     qc.measure(i, i)
#
# File /opt/anaconda3/envs/qiskit/lib/python3.12/site-packages/qiskit/circuit/quantumcircuit.py:4338, in QuantumCircuit.measure(self, qubit, cbit)
#    4249 r"""Measure a quantum bit (``qubit``) in the Z basis into a classical bit (``cbit``).
#    4250
#    4251 When a quantum state is measured, a qubit is projected in the computational (Pauli Z) basis
#    (...)   4334
#    4335 """
#    4336 from .measure import Measure
# -> 4338 return self.append(Measure(), [qubit], [cbit], copy=False)
#
# File /opt/anaconda3/envs/qiskit/lib/python3.12/site-packages/qiskit/circuit/quantumcircuit.py:2744, in QuantumCircuit.append(self, instruction, qargs, cargs, copy)
#    2738         raise CircuitError(
# ...
