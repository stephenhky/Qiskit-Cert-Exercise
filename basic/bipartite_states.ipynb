# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, DensityMatrix
from qiskit.visualization import plot_state_city

# %%
epr_circuit = QuantumCircuit(2)
epr_circuit.h(0)
epr_circuit.cx(0, 1)

# %%
epr_circuit.draw("mpl")

# %%
# ev = Statevector.from_int(0, 4)
ev = Statevector.from_label("00")
ev_vec1 = ev.evolve(epr_circuit)

# %%
ev_vec1.draw("latex")
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
ev_vec1.draw("qsphere")

# %%
ev_vec1.draw("hinton")

# %%
plot_state_city(DensityMatrix(epr_circuit))

# %%
singlet_circuit = QuantumCircuit(2)
singlet_circuit.h(0)
singlet_circuit.x(1)
singlet_circuit.cx(0, 1)

# %%
singlet_circuit.draw("mpl")

# %%
ev_vec2 = ev.evolve(singlet_circuit)

# %%
ev_vec2.draw("latex")
# Out:
# $$\frac{\sqrt{2}}{2} |01\rangle+\frac{\sqrt{2}}{2} |10\rangle$$

# %%
ev_vec2.draw("qsphere")

# %%
ev_vec2.draw("hinton")

# %%
plot_state_city(DensityMatrix(singlet_circuit))
