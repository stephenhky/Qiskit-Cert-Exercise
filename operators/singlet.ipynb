# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, DensityMatrix, Operator

# %%
singlet_qc = QuantumCircuit(2)
singlet_qc.h(0)
singlet_qc.x(1)
singlet_qc.cx(0, 1)

# %%
singlet_qc.draw("mpl")

# %%
ev = Statevector.from_label("00")

# %%
ev1 = ev.evolve(singlet_qc)

# %%
ev1.draw("latex")
# Out:
# $$\frac{\sqrt{2}}{2} |01\rangle+\frac{\sqrt{2}}{2} |10\rangle$$

# %%
denmat = DensityMatrix.from_label("00")

# %%
denmat
# Out:
# DensityMatrix([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#                [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#                [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#                [0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j]],
#               dims=(2, 2))

# %%
denmat.evolve(singlet_qc)
# Out:
# DensityMatrix([[0. +0.j, 0. +0.j, 0. +0.j, 0. +0.j],
#                [0. +0.j, 0.5+0.j, 0.5+0.j, 0. +0.j],
#                [0. +0.j, 0.5+0.j, 0.5+0.j, 0. +0.j],
#                [0. +0.j, 0. +0.j, 0. +0.j, 0. +0.j]],
#               dims=(2, 2))

# %%
singlet_qc_operator = Operator(singlet_qc)

# %%
singlet_qc_operator
# Out:
# Operator([[ 0.        +0.j,  0.        +0.j,  0.70710678+0.j,
#             0.70710678+0.j],
#           [ 0.70710678+0.j, -0.70710678+0.j,  0.        +0.j,
#             0.        +0.j],
#           [ 0.70710678+0.j,  0.70710678+0.j,  0.        +0.j,
#             0.        +0.j],
#           [ 0.        +0.j,  0.        +0.j,  0.70710678+0.j,
#            -0.70710678+0.j]],
#          input_dims=(2, 2), output_dims=(2, 2))

# %%
denmat.evolve(singlet_qc_operator)
# Out:
# DensityMatrix([[0. +0.j, 0. +0.j, 0. +0.j, 0. +0.j],
#                [0. +0.j, 0.5+0.j, 0.5+0.j, 0. +0.j],
#                [0. +0.j, 0.5+0.j, 0.5+0.j, 0. +0.j],
#                [0. +0.j, 0. +0.j, 0. +0.j, 0. +0.j]],
#               dims=(2, 2))

# %%
type(singlet_qc_operator)
# Out:
# qiskit.quantum_info.operators.operator.Operator

# %%
isinstance(singlet_qc_operator, np.ndarray)
# Out:
# False

# %% [markdown]
# # Testing Matrix

# %%
step1_qc = QuantumCircuit(2)
step1_qc.h(0)

# %%
step1_qc.draw("mpl")

# %%
Operator(step1_qc)
# Out:
# Operator([[ 0.70710678+0.j,  0.70710678+0.j,  0.        +0.j,
#             0.        +0.j],
#           [ 0.70710678+0.j, -0.70710678+0.j,  0.        +0.j,
#             0.        +0.j],
#           [ 0.        +0.j,  0.        +0.j,  0.70710678+0.j,
#             0.70710678+0.j],
#           [ 0.        +0.j,  0.        +0.j,  0.70710678+0.j,
#            -0.70710678+0.j]],
#          input_dims=(2, 2), output_dims=(2, 2))

# %%
step2_qc = QuantumCircuit(2)
step2_qc.x(1)

# %%
step2_qc.draw("mpl")

# %%
Operator(step2_qc)
# Out:
# Operator([[0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#           [1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j]],
#          input_dims=(2, 2), output_dims=(2, 2))

# %%
step3_qc = QuantumCircuit(2)
step3_qc.cx(0, 1)

# %%
Operator(step3_qc)
# Out:
# Operator([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#           [0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j],
#           [0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j]],
#          input_dims=(2, 2), output_dims=(2, 2))
