# %%
from qiskit.circuit.library import CZGate
from qiskit import QuantumRegister, QuantumCircuit
from qiskit.quantum_info import Statevector

# %%
qr = QuantumRegister(3)
ar = QuantumRegister(1)

qc = QuantumCircuit(qr, ar)
qc.h(qr)
qc.x(ar)
qc.h(ar)

# %%
Statevector.from_instruction(qc)
# Out:
# Statevector([ 0.25+0.j,  0.25+0.j,  0.25+0.j,  0.25+0.j,  0.25+0.j,
#               0.25+0.j,  0.25+0.j,  0.25+0.j, -0.25+0.j, -0.25+0.j,
#              -0.25+0.j, -0.25+0.j, -0.25+0.j, -0.25+0.j, -0.25+0.j,
#              -0.25+0.j],
#             dims=(2, 2, 2, 2))

# %%
qc.mcx([qr[0], qr[1]], qr[2])

# %%
Statevector.from_instruction(qc)
# Out:
# Statevector([0.35355339+0.j, 0.35355339+0.j, 0.35355339+0.j,
#              0.35355339+0.j, 0.35355339+0.j, 0.35355339+0.j,
#              0.35355339+0.j, 0.35355339+0.j],
#             dims=(2, 2, 2))

# %%
qc.h(qr)

# %%
Statevector.from_instruction(qc)
# Out:
# Statevector([ 1.00000000e+00+0.j,  6.22328532e-19+0.j,  9.52420783e-18+0.j,
#               1.92058443e-35+0.j,  2.36158002e-17+0.j, -1.21839471e-35+0.j,
#               1.26316153e-34+0.j,  1.90505075e-52+0.j],
#             dims=(2, 2, 2))
